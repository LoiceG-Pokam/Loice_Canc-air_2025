# %%
import pandas as pd
import psycopg2
import pandas as pd
import geopandas as gpd
import requests
from geopandas.tools import sjoin
import time
import datetime
from collections import Counter 
import re
import random
import numpy as np
import os

# %% [markdown]
# ## Ajout du bruit dans nos données pour les géocodées ensuite :

# %% [markdown]
# #### Bruit unique :

# %%
liste_biais = [["RESIDENCE",3],["CHEZ",2],["BAT",5],["APPT",5],["MME",3],["MR",4],["RES",3],["HOPITAL",3],["MAISON",4],["RETRAITE",6],["CENTRE",4],["HOTEL",5],["QUARTIER",2]]
liste_nom_propre = ["CHARLES DE GAULLES", "JEAN MOULIN", "MARIE CURIE", "Foch"]

def add_bruit_unique(df, biais, pos_bruit, taux_bruit):

    df_bruite = df.copy() 

    #df_bruite = df_bruite.reset_index(drop=True)

    for i in df_bruite.index:

        adresse_part = str(df_bruite.at[i,"adresse"]).split(" ")
        adresse_part = ' '.join(adresse_part).split() ## suppression str vides 

        if pos_bruit > len(adresse_part):
            adresse_part.insert(len(adresse_part),biais)
        else :
            adresse_part.insert(pos_bruit,biais)
        df_bruite.at[i, "adresse"] = " ".join(adresse_part)

    return df_bruite

# %%
liste_biais = [["RESIDENCE",3],["CHEZ",2],["BAT",5],["APPT",5],["MME",3],["MR",4],["RES",3],["HOPITAL",3],["MAISON",4],["RETRAITE",6],["CENTRE",4],["HOTEL",5],["QUARTIER",2]]
liste_nom_propre = [" CHARLES DE GAULLES", " JEAN MOULIN", " MARIE CURIE", " FOCH"]

def add_bruit_unique_joint(df, biais, pos_bruit, taux_bruit):

    df_bruite = df.copy() 

    #df_bruite = df_bruite.reset_index(drop=True)

    for i in df_bruite.index:

        adresse_part = str(df_bruite.at[i,"adresse"]).split(" ")
        adresse_part = ' '.join(adresse_part).split() ## suppression str vides 

        ## Génération aléatoire du nom propre : 
        j = random.randint(0,3)
        biais_np = biais + liste_nom_propre[j]

        if pos_bruit > len(adresse_part):
            adresse_part.insert(len(adresse_part),biais_np)
        else :
            adresse_part.insert(pos_bruit,biais_np)
        df_bruite.at[i, "adresse"] = " ".join(adresse_part)

    return df_bruite

# %% [markdown]
# ### Pour nos données de référence :

# %%
df_ref_ini = pd.read_csv("./ecoles/fr-en-adresse-et-geolocalisation-etablissements-premier-et-second-degre.csv", sep=";")

col_to_keep=['numero_uai','adresse_uai','code_postal_uai','libelle_commune','coordonnee_x', 'coordonnee_y', 'epsg', 'latitude',
       'longitude', 'appariement', 'localisation','code_departement', 'code_region']
df_ref_ini = df_ref_ini[col_to_keep]

reg_metrop = [11,24,27,28,32,44,54,53,75,76,84,93,94]
df_ref_ini = df_ref_ini[df_ref_ini["code_region"].isin(reg_metrop)]
df_ref_ini.rename(columns={'adresse_uai': 'adresse'}, inplace=True)

df_ref_ini = df_ref_ini.sample(n=1000).reset_index()

# %%
# Dictionnaire pour stocker les DataFrames
df_ref_biais = {}


# Boucle pour appliquer le bruit à chaque biais
for biais, pos_bruit in liste_biais:
    df_ref_biais[f"df_ref_{biais}"] = add_bruit_unique(df_ref_ini,biais,pos_bruit, 1)
    df_ref_biais[f"df_ref_{biais}_np"] = add_bruit_unique_joint(df_ref_ini,biais,pos_bruit, 1)

# %%
df_ref_biais["df_ref_RESIDENCE_np"].head()
# Out:
#    index numero_uai                                            adresse  \
# 0  30944   0593155J         28 rue du RESIDENCE FOCH Faubourg de Paris
# 1  56074   0790338N  64 rue Mal RESIDENCE MARIE CURIE de Lattre de ...
# 2  44621   0390445X  2 place des RESIDENCE CHARLES DE GAULLES Tilleuls
# 3  47169   0351730R           1 rue de RESIDENCE MARIE CURIE la Pensée
# 4  14418   0190097C                          nan RESIDENCE JEAN MOULIN
#
#    code_postal_uai       libelle_commune  coordonnee_x  coordonnee_y  \
# 0            59300          Valenciennes      736633.7     7028662.7
# 1            79380    La Forêt-sur-Sèvre      421543.0     6636261.7
# 2            39110           Aiglepierre      914403.2     6654091.8
# 3            35660  La Chapelle-de-Brain      330059.6     6744858.8
# 4            19310     Perpezac-le-Blanc      569035.9     6459494.0
#
#         epsg   latitude  longitude appariement   localisation  \
# 0  EPSG:2154  50.354606   3.514070    Parfaite  Numéro de rue
# 1  EPSG:2154  46.768547  -0.650226    Parfaite  Numéro de rue
# 2  EPSG:2154  46.952573   5.819720    Parfaite  Numéro de rue
# 3  EPSG:2154  47.700029  -1.935641    Parfaite  Numéro de rue
# 4  EPSG:2154  45.222319   1.331260    Correcte          Ville
#
#   code_departement  code_region
# 0              059           32
# 1              079           75
# 2              039           27
# 3              035           53
# 4              019           75

# %% [markdown]
# ### Préparation données pour géocodage :

# %%
def ref_to_geocoding(df):
    df["requete"] =df['adresse'] + " " + str(df["code_postal_uai"])+ " " + df["libelle_commune"]
    return df

# %%
##Biais unique

for nom_df, df in df_ref_biais.items():
    df_modifie = ref_to_geocoding(df)
    df_ref_biais[nom_df] = df_modifie
    print(f"DataFrame: {nom_df} prêt à être géocodé")
    print("---")

# ##Biais joint 
# for nom_df, df in df_ref_biais_joint.items():
#     df_modifie = ref_to_geocoding(df)
#     df_ref_biais_joint[nom_df] = df_modifie
#     print(f"DataFrame: {nom_df} prêt à être géocodé")
#     print("---")
# Out:
# DataFrame: df_ref_RESIDENCE prêt à être géocodé
# ---
# DataFrame: df_ref_RESIDENCE_np prêt à être géocodé
# ---
# DataFrame: df_ref_CHEZ prêt à être géocodé
# ---
# DataFrame: df_ref_CHEZ_np prêt à être géocodé
# ---
# DataFrame: df_ref_BAT prêt à être géocodé
# ---
# DataFrame: df_ref_BAT_np prêt à être géocodé
# ---
# DataFrame: df_ref_APPT prêt à être géocodé
# ---
# DataFrame: df_ref_APPT_np prêt à être géocodé
# ---
# DataFrame: df_ref_MME prêt à être géocodé
# ---
# DataFrame: df_ref_MME_np prêt à être géocodé
# ---
# DataFrame: df_ref_MR prêt à être géocodé
# ---
# DataFrame: df_ref_MR_np prêt à être géocodé
# ---
# DataFrame: df_ref_RES prêt à être géocodé
# ---
# DataFrame: df_ref_RES_np prêt à être géocodé
# ---
# DataFrame: df_ref_HOPITAL prêt à être géocodé
# ---
# DataFrame: df_ref_HOPITAL_np prêt à être géocodé
# ---
# DataFrame: df_ref_MAISON prêt à être géocodé
# ---
# DataFrame: df_ref_MAISON_np prêt à être géocodé
# ---
# DataFrame: df_ref_RETRAITE prêt à être géocodé
# ---
# DataFrame: df_ref_RETRAITE_np prêt à être géocodé
# ---
# DataFrame: df_ref_CENTRE prêt à être géocodé
# ---
# DataFrame: df_ref_CENTRE_np prêt à être géocodé
# ---
# DataFrame: df_ref_HOTEL prêt à être géocodé
# ---
# DataFrame: df_ref_HOTEL_np prêt à être géocodé
# ---
# DataFrame: df_ref_QUARTIER prêt à être géocodé
# ---
# DataFrame: df_ref_QUARTIER_np prêt à être géocodé
# ---

# %%
import requests
r = requests.get('https://addok-data.curie.net/search?q=25 rue d ulm 75005 PARIS')#+df["requete"][0])
print(r)
response = r.json()

# %%
def geocode(df,liste_biais, join = False):
    """Geocode dataframe with Etalab addok"""
    name =[x for x in globals() if globals()[x] is df][0]
    print(f"Proceed to geocode on address for {name}...")
    
    for i in df.index:
        try:
            # get json response
            r = requests.get('https://addok-data.curie.net/search?q='+df["requete"][i])
            response = r.json()

            if i%10000==0 : 
                print(f"Proceed geocoding at the {i}th row")
            if response["features"]!=[]:
                # parse json to insert value in dataframe
                df.at[i, 'x'] = str(response["features"][0]["geometry"]["coordinates"][0])
                df.at[i, 'y'] = str(response["features"][0]["geometry"]["coordinates"][1])
                df.at[i, 'score'] = str(response["features"][0]["properties"]["score"])

                if float(df["score"][i])<0.4:
                    df.at[i, 'trust_score'] = 'low'
                elif float(df["score"][i])>0.4 and float(df["score"][i])<0.65:
                    df.at[i, 'trust_score'] = 'middle'
                elif float(df["score"][i])>0.65 and float(df["score"][i])<0.9:
                    df.at[i, 'trust_score'] = 'middle'
                else:
                    df.at[i, 'trust_score'] = 'high'

                df.at[i, 'street'] = str(response["features"][0]["properties"]["name"]).replace("'", " ")
                df.at[i, 'city'] = str(response["features"][0]["properties"]["city"]).replace("'", " ")
                df.at[i, 'pc_city'] = str(response["features"][0]["properties"]["postcode"])
                df.at[i, 'ic_city'] = str(response["features"][0]["properties"]["citycode"])

                context = (str(response["features"][0]["properties"]["context"]).replace("'", " ")).split(",")
                df.at[i, 'code_dept'] = context[0]
                df.at[i, 'dept'] = context[1]

                if len(df["code_dept"][i])==2:
                    df.at[i, 'reg'] = context[2]
                else:
                    df.at[i, 'reg'] = "other"

                df.at[i, "address"] = str(response["features"][0]["properties"]["label"]).replace("'", " ")
                
                if (df["adresse"][i].lstrip())[0].isdigit():
                    df.at[i, 'address_has_num_init'] = "true"
                else:
                    df.at[i, 'address_has_num_init'] = "false"
                    
                if (df["street"][i].lstrip())[0].isdigit():
                    df.at[i, 'address_has_num_geoloc'] = "true"
                else:
                    df.at[i, 'address_has_num_geoloc'] = "false"
                    
                if df["codepost"][i] == df["pc_city"][i]:
                    df.at[i, 'same_city'] = "true"
                else:
                    df.at[i, 'same_city'] = "false" 

                ##Analyse biais : 
                for mot in liste_biais: 
                    if join : 
                        if mot[0] and mot[1] in df["adresse"].str.split(" ") : 
                            df.at[i,f"adresse_has_{mot[0]}_{mot[1]}_init"] = True 
                    else : 
                        if mot in df["adresse"].str.split(' '):
                            df.at[i,f"adresse_has_{mot}_init"] = True 
                        else : 
                            df.at[i,f"adresse_has_{mot}_init"] = False 

                    
                ## Check up si mot "hotel" et "chez" sont présent dans la réponse du géocodage?     
                # if "hotel" in df["street"][i] or "hôtel" in df["street"][i]: 
                #     df.at[i, 'hostel'] = "true"
                # else:
                #     df.at[i, 'hostel'] = "false"

                # if "chez" in df["street"][i]: 
                #     df.at[i, 'hosted'] = "true"
                # else:
                #     df.at[i, 'hosted'] = "false"
                    
                df.at[i, 'date_geoloc'] = str(datetime.date.today())
                #df.at[i, 'etalab_version'] = str(response["licence"])
                #df.at[i, 'ban_version'] = "2021-04-27"
            else:
                pass
        except:
            pass
    return df

def spatialjoin(df, df_iris, df_epci, df_dept):
    """Spatial join of the database and the iris/epci layers"""
    name =[x for x in globals() if globals()[x] is df][0]
    print(f"Perfom to spatial join on IRIS and EPCI layers for {name}...")
    gdf = (gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.x, df.y)).set_crs(epsg=4326)).to_crs(epsg=2154)

    df_join_iris = gpd.sjoin(gdf, df_iris[['CODE_IRIS','geometry']], how="left", op='within')
    df_join_iris.drop('index_right', axis=1, inplace=True)

    df_epci =df_epci.to_crs(epsg=2154)
    df_join_iris_epci = gpd.sjoin(df_join_iris, df_epci[['CODE_EPCI','geometry']], how="left", op='within')
    df_join_iris_epci.drop('index_right', axis=1, inplace=True)

    df_join_iris_epci_dept = gpd.sjoin(df_join_iris_epci, df_dept[['CODE_DEPT','geometry']], how="left", op='within')
    df_join_iris_epci_dept.drop('index_right', axis=1, inplace=True)
    return df_join_iris_epci_dept

# %%
df_iris = gpd.read_file('H:/canc_air/data/zones_geographiques/iris/CONTOURS-IRIS.shp')
df_epci = gpd.read_file('H:/canc_air/data/zones_geographiques/epci/EPCI_SHAPEFILE.shp')
df_dept = gpd.read_file('H:/canc_air/data/zones_geographiques/departements/DEPARTEMENT.shp')

# %%
df_ref_biais_geocoded = {}

for nom_df, df in df_ref_biais.items():
    df_geocoded = geocode(df,liste_biais)
    print(f"{nom_df} géocodé")
    df_geo_spatial = spatialjoin(df_geocoded, df_iris, df_epci, df_dept)
    df_ref_biais_geocoded[nom_df] = df_geo_spatial
    df_geo_spatial.to_csv(f"../geocodeur/data_with_biais/ref_unique_biais/{nom_df}.csv",sep=";")
    print(f"{nom_df} jointure spatiale faite")
    print("---")
# Out:
# Proceed to geocode on address for df...
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # STOP MISE A JOUR

# %% [markdown]
# #### Bruit joint

# %%
liste_biais_joint = [[('CHEZ','MME'),(2,3)],[('CHEZ','MR'),(2,3)],[('APPT', 'BAT'),(7,5)],[('RESIDENCE','BAT'),(4,7)],[('RESIDENCE','APPT'),(2,6)]]

def add_bruit_joint(df, biais, pos_bruit,taux_bruit):

    nb_lignes_bruit = int(len(df) * taux_bruit)

    df_bruite = df.copy() 

    df_bruite = df_bruite.reset_index(drop=True)

    index_bruit = random.sample(range(len(df_bruite)), nb_lignes_bruit)
    for i in index_bruit:
        adresse_part = str(df_bruite.at[i,"adresse"]).split(" ")
        adresse_part = ' '.join(adresse_part).split() ## suppression str vides 

        if biais[0] or biais[1] not in adresse_part:
            pos_0 = pos_bruit[0] > len(adresse_part)
            pos_1 = pos_bruit[1] > len(adresse_part)
            if pos_0 is True and pos_1 is True:
                # adresse_part = adresse_part[:len(adresse_part)] + biais[0] + adresse_part[len(adresse_part):]
                adresse_part.insert(len(adresse_part),biais[0])
                adresse_part.insert(len(adresse_part),biais[1])
            elif pos_0 is True and pos_1 is False :
                adresse_part.insert(len(adresse_part),biais[0])
                adresse_part.insert(pos_bruit[1],biais[1])
            elif pos_0 is False and pos_1 is True :
                adresse_part.insert(pos_bruit[0],biais[0])
                adresse_part.insert(len(adresse_part),biais[1])
            else : 
                adresse_part.insert(pos_bruit[0],biais[0])
                adresse_part.insert(pos_bruit[1],biais[1])
            df_bruite.at[i, "adresse"] = " ".join(adresse_part)
    return df_bruite

# %%
# Dictionnaire pour stocker les DataFrames
df_patients_biais_joint = {}

# Boucle pour appliquer le bruit à chaque biais
for biais,pos_bruit in liste_biais_joint:
    df_patients_biais_joint[f"df_patient_{str(biais[0]+"_"+biais[1])}"] = add_bruit_joint(df_patients_ini, biais, list(pos_bruit), 0.5)

# %% [markdown]
# #### Patients

# %%
def patient_to_geocoding(df):
    df["requete"] =df['adresse'] + " " + df["codepost"]+ " " + df["nom_commune_postal"]
    return df

# %%
##Biais unique

for nom_df, df in df_patients_biais.items():
    df_modifie = patient_to_geocoding(df)
    df_patients_biais[nom_df] = df_modifie
    print(f"DataFrame: {nom_df} prêt à être géocodé")
    print("---")

##Biais joint 
for nom_df, df in df_patients_biais_joint.items():
    df_modifie = patient_to_geocoding(df)
    df_patients_biais_joint[nom_df] = df_modifie
    print(f"DataFrame: {nom_df} prêt à être géocodé")
    print("---")
# Out:
# DataFrame: df_patients_RESIDENCE prêt à être géocodé
# ---
# DataFrame: df_patients_CHEZ prêt à être géocodé
# ---
# DataFrame: df_patients_BAT prêt à être géocodé
# ---
# DataFrame: df_patients_APPT prêt à être géocodé
# ---
# DataFrame: df_patients_MME prêt à être géocodé
# ---
# DataFrame: df_patients_MR prêt à être géocodé
# ---
# DataFrame: df_patients_RES prêt à être géocodé
# ---
# DataFrame: df_patients_HOPITAL prêt à être géocodé
# ---
# DataFrame: df_patients_MAISON prêt à être géocodé
# ---
# DataFrame: df_patients_RETRAITE prêt à être géocodé
# ---
# DataFrame: df_patients_CENTRE prêt à être géocodé
# ---
# DataFrame: df_patients_HOTEL prêt à être géocodé
# ---
# DataFrame: df_patients_QUARTIER prêt à être géocodé
# ---
# DataFrame: df_patient_CHEZ_MME prêt à être géocodé
# ---
# DataFrame: df_patient_CHEZ_MR prêt à être géocodé
# ---
# DataFrame: df_patient_APPT_BAT prêt à être géocodé
# ---
# DataFrame: df_patient_RESIDENCE_BAT prêt à être géocodé
# ---
# DataFrame: df_patient_RESIDENCE_APPT prêt à être géocodé
# ---

# %% [markdown]
# #### Références

# %%
# Out:
# DataFrame: df_ref_RESIDENCE prêt à être géocodé
# ---
# DataFrame: df_ref_CHEZ prêt à être géocodé
# ---
# DataFrame: df_ref_BAT prêt à être géocodé
# ---
# DataFrame: df_ref_APPT prêt à être géocodé
# ---
# DataFrame: df_ref_MME prêt à être géocodé
# ---
# DataFrame: df_ref_MR prêt à être géocodé
# ---
# DataFrame: df_ref_RES prêt à être géocodé
# ---
# DataFrame: df_ref_HOPITAL prêt à être géocodé
# ---
# DataFrame: df_ref_MAISON prêt à être géocodé
# ---
# DataFrame: df_ref_RETRAITE prêt à être géocodé
# ---
# DataFrame: df_ref_CENTRE prêt à être géocodé
# ---
# DataFrame: df_ref_HOTEL prêt à être géocodé
# ---
# DataFrame: df_ref_QUARTIER prêt à être géocodé
# ---
# DataFrame: df_ref_CHEZ_MME prêt à être géocodé
# ---
# DataFrame: df_ref_CHEZ_MR prêt à être géocodé
# ---
# DataFrame: df_ref_APPT_BAT prêt à être géocodé
# ---
# DataFrame: df_ref_RESIDENCE_BAT prêt à être géocodé
# ---
# DataFrame: df_ref_RESIDENCE_APPT prêt à être géocodé
# ---

# %% [markdown]
# # Géocodage sur nos données bruitées :

# %%
df = df_dept.head()
df.to_csv("../geocodeur/data_with_biais/ref_join_biais/test.csv", sep=";")

# %%
# df_patients_biais_geocoded = {}

# for nom_df, df in df_patients_biais.items():
#     # if os.path.isfile(f"../geocodeur/data_with_biais/patients_unique_biais/{nom_df}.csv") is not True:
#     df_geocoded = geocode(df,liste_biais)
#     print(f"{nom_df} géocodé")
#     df_geo_spatial = spatialjoin(df_geocoded, df_iris, df_epci, df_dept)
#     df_patients_biais_geocoded[nom_df] = df_geo_spatial
#     df_geo_spatial.to_csv(f"../geocodeur/data_with_biais/patients_unique_biais/{nom_df}.csv",sep=";")
#     print(f"{nom_df} jointure spatiale faite")
#     print("---")


df_patients_biais_joint_geocoded = {}

for nom_df, df in df_patients_biais_joint.items():
    df_geocoded = geocode(df,liste_biais_joint, join = True)
    print(f"{nom_df} géocodé")
    df_geo_spatial = spatialjoin(df_geocoded, df_iris, df_epci, df_dept)
    df_patients_biais_joint_geocoded[nom_df] = df_geo_spatial
    df_geo_spatial.to_csv(f"../geocodeur/data_with_biais/patients_join_biais/{nom_df}.csv",sep=";")
    print(f"{nom_df} jointure spatiale faite")
    print("---")

df_ref_biais_geocoded = {}

for nom_df, df in df_ref_biais.items():
    df_geocoded = geocode(df,liste_biais)
    print(f"{nom_df} géocodé")
    df_geo_spatial = spatialjoin(df_geocoded, df_iris, df_epci, df_dept)
    df_ref_biais_geocoded[nom_df] = df_geo_spatial
    df_geo_spatial.to_csv(f"../geocodeur/data_with_biais/ref_unique_biais/{nom_df}.csv",sep=";")
    print(f"{nom_df} jointure spatiale faite")
    print("---")

df_ref_biais_joint_geocoded = {}

for nom_df, df in df_ref_biais_joint.items():
    df_geocoded = geocode(df,liste_biais_joint, join = True)
    print(f"{nom_df} géocodé")
    df_geo_spatial = spatialjoin(df_geocoded, df_iris, df_epci, df_dept)
    df_ref_biais_joint_geocoded[nom_df] = df_geo_spatial
    df_geo_spatial.to_csv(f"../geocodeur/data_with_biais/ref_join_biais/{nom_df}.csv",sep=";")
    print(f"{nom_df} jointure spatiale faite")
    print("---")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 16
#       1 # df_patients_biais_geocoded = {}
#       2
#       3 # for nom_df, df in df_patients_biais.items():
#    (...)
#      10 #     print(f"{nom_df} jointure spatiale faite")
#      11 #     print("---")
#      14 df_patients_biais_joint_geocoded = {}
# ---> 16 for nom_df, df in df_patients_biais_joint.items():
#      17     df_geocoded = geocode(df,liste_biais_joint, join = True)
#      18     print(f"{nom_df} géocodé")
#
# NameError: name 'df_patients_biais_joint' is not defined

# %%
## Geocoding biais with associated elements : 

liste_biais_associated =["RESIDENCE CHARLES DE GAULLES", "HOTEL FOCH"]

def add_bruit_RES(df):
     
    nb_lignes_bruit = int(len(df) * 0.5)

    df_bruite = df.copy() 

    df_bruite = df_bruite.reset_index(drop=True)

    index_bruit = random.sample(range(len(df_bruite)), nb_lignes_bruit)

    for i in index_bruit:
        adresse_part = str(df_bruite.at[i,"adresse"]).split(" ")
        adresse_part = ' '.join(adresse_part).split() ## suppression str vides 
        adresse_part.insert(0,liste_biais_associated[0])
        df_bruite.at[i, "adresse"] = " ".join(adresse_part)

    return df_bruite

def add_bruit_HOTEL(df):
     
    nb_lignes_bruit = int(len(df) * 0.5)

    df_bruite = df.copy() 

    df_bruite = df_bruite.reset_index(drop=True)

    index_bruit = random.sample(range(len(df_bruite)), nb_lignes_bruit)

    for i in index_bruit:
        adresse_part = str(df_bruite.at[i,"adresse"]).split(" ")
        adresse_part = ' '.join(adresse_part).split() ## suppression str vides 
        adresse_part.insert(0,liste_biais_associated[1])
        df_bruite.at[i, "adresse"] = " ".join(adresse_part)

    return df_bruite

df_ref_RES_elem = add_bruit_RES(df_ref_ini)
df_ref_HOTEL_elem = add_bruit_HOTEL(df_ref_ini)

df_RES_elem = ref_to_geocoding(df_ref_RES_elem)
df_HOTEL_elem = ref_to_geocoding(df_ref_HOTEL_elem)



df_geocoded_RES = geocode(df_RES_elem,liste_biais)
print(f"{nom_df} géocodé")
df_geo_spatial_RES = spatialjoin(df_geocoded_RES, df_iris, df_epci, df_dept)
df_geo_spatial_RES.to_csv("./data_with_biais/ref_biais_elem/df_ref_RES_CDG.csv",sep=";")

df_geocoded_HOTEL = geocode(df_HOTEL_elem,liste_biais)
print(f"{nom_df} géocodé")
df_geo_spatial_HOTEL = spatialjoin(df_geocoded_HOTEL, df_iris, df_epci, df_dept)
df_geo_spatial_HOTEL.to_csv("./data_with_biais/ref_biais_elem/df_ref_HOTEL_FOCH.csv",sep=";")
